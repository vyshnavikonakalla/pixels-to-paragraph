# %%
from PIL import Image
import generate  # Import your caption generation function

def generate_caption_for_image(image_path):
    caption = generate.runModel(image_path)
    return caption

if __name__ == "__main__":
    image_path = "data/Images/10957138.jpg"  # Replace with the path to your image
    caption = generate_caption_for_image(image_path)
    print(f"Image Caption: {caption}")
# Out:
# Loading the model...
# Encoding the image ...
# 1/1 [==============================] - 1s 1s/step
# Running model to generate the caption...
# ...
# 1/1 [==============================] - 0s 36ms/step
# a young girl in a bathing suit is running through the water
# Image Caption: a young girl in a bathing suit is running through the water

# %%
from PIL import Image
import generate  # Import your caption generation function

def generate_caption_for_image(image_path):
    caption = generate.runModel(image_path)
    return caption

if __name__ == "__main__":
    image_path = "data/Images/15874606.jpg"  # Replace with the path to your image
    caption = generate_caption_for_image(image_path)
    print(f"Image Caption: {caption}")
# Out:
# Encoding the image ...
# 1/1 [==============================] - 0s 186ms/step
# Running model to generate the caption...
# ...
# 1/1 [==============================] - 0s 38ms/step
# a man in a blue shirt is swimming in a pool
# Image Caption: a man in a blue shirt is swimming in a pool

# %%
from PIL import Image
import generate  # Import your caption generation function

def generate_caption_for_image(image_path):
    caption = generate.runModel(image_path)
    return caption

if __name__ == "__main__":
    image_path = "data/Images/22930048.jpg"  # Replace with the path to your image
    caption = generate_caption_for_image(image_path)
    print(f"Image Caption: {caption}")
# Out:
# Encoding the image ...
# 1/1 [==============================] - 0s 169ms/step
# Running model to generate the caption...
# ...
# 1/1 [==============================] - 0s 56ms/step
# a woman in a white shirt is playing tennis
# Image Caption: a woman in a white shirt is playing tennis
